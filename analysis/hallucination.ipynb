# %%
import json
import os

path_prefix = "/home/jyc/prefix-learning/analysis/records/vqav2"
data = {
    "vqav2": {
        "path": [
            os.path.join(path_prefix, p)
            for p in [
                "icl-32-shot.json",
                "licv.json",
                "lora-r-16.json",
                "mimic.json",
            ]
        ],
        "data": {},
    }
}
for name, item in data.items():
    for p in item["path"]:
        raw_file = json.load(open(p))
        if p != os.path.join(path_prefix, "icl-32-shot.json"):
            data[name]["data"][p] = raw_file["records"]
        else:
            data[name]["data"][p] = raw_file

# %%
import re


def post_process(text):
    text = re.split(r"Question|\n|Short|Answer", text, 1)[0]
    return re.sub(r"[^\w\s]", "", text).strip().lower()


def collect_yes_no_hallucination(record):
    yes_no_but_other = []
    other_but_yes_no = []
    if isinstance(record, dict):
        record = record.values()
    for item in record:
        answer_type = item["answer_type"]
        pred = post_process(item["prediction"])
        meta_info = {
            "answer_type": answer_type,
            "prediction": item["prediction"],
            "question_id": item["question_id"],
            "question": item["question"] if "question" in item else "",
            # "answer": item["answer"],
        }

        if answer_type != "yes/no" and (pred == "yes" or pred == "no"):
            other_but_yes_no.append(meta_info)
        elif answer_type == "yes/no" and (pred != "yes" and pred != "no"):
            yes_no_but_other.append(meta_info)

    return yes_no_but_other, other_but_yes_no


def collect_number_hallucination(record):
    other_but_number = []
    numer_but_other = []
    if isinstance(record, dict):
        record = record.values()
    manual_mapping = {
        "none": "0",
        "zero": "0",
        "one": "1",
        "two": "2",
        "three": "3",
        "four": "4",
        "five": "5",
        "six": "6",
        "seven": "7",
        "eight": "8",
        "nine": "9",
        "ten": "10",
    }
    for item in record:
        answer_type = item["answer_type"]
        pred = post_process(item["prediction"])
        meta_info = {
            "answer_type": answer_type,
            "prediction": item["prediction"],
            "question_id": item["question_id"],
            "question": item["question"],
            # "answer": item["answer"],
        }
        if answer_type != "number" and (pred.isdigit() or pred in manual_mapping):
            other_but_number.append(meta_info)
        elif answer_type == "number" and (
            (not pred.isdigit()) and pred not in manual_mapping
        ):
            other_but_number.append(meta_info)

    return numer_but_other, other_but_number


for name, item in data.items():
    for p in item["path"]:
        print(os.path.basename(p))
        yes_no_but_other, other_but_yes_no = collect_yes_no_hallucination(
            item["data"][p]
        )
        print(yes_no_but_other)
        print(other_but_yes_no)
        print(len(yes_no_but_other), len(other_but_yes_no))
# Out:
# icl-32-shot.json
# [{'answer_type': 'yes/no', 'prediction': 'turtles', 'question_id': 152499003, 'question': ''}, {'answer_type': 'yes/no', 'prediction': 'blender', 'question_id': 210108002, 'question': ''}, {'answer_type': 'yes/no', 'prediction': 'old Question', 'question_id': 248019008, 'question': ''}, {'answer_type': 'yes/no', 'prediction': 'crumbs', 'question_id': 417023010, 'question': ''}, {'answer_type': 'yes/no', 'prediction': 'white Question', 'question_id': 479440017, 'question': ''}]
# [{'answer_type': 'other', 'prediction': 'no Question', 'question_id': 19047002, 'question': ''}, {'answer_type': 'other', 'prediction': 'no Question', 'question_id': 36557000, 'question': ''}, {'answer_type': 'other', 'prediction': 'no Question', 'question_id': 38321004, 'question': ''}, {'answer_type': 'number', 'prediction': 'yes Question', 'question_id': 38685000, 'question': ''}, {'answer_type': 'other', 'prediction': 'no Question', 'question_id': 50124014, 'question': ''}, {'answer_type': 'number', 'prediction': 'yes Question', 'question_id': 70256000, 'question': ''}, {'answer_type': 'other', 'prediction': 'no Question', 'question_id': 76721002, 'question': ''}, {'answer_type': 'other', 'prediction': 'no Question', 'question_id': 148620000, 'question': ''}, {'answer_type': 'other', 'prediction': 'no Question', 'question_id': 149431002, 'question': ''}, {'answer_type': 'number', 'prediction': 'no Question', 'question_id': 157866002, 'question': ''}, {'answer_type': 'other', 'prediction': 'no Question', 'question_id': 170739001, 'question': ''}, {'answer_type': 'other', 'prediction': 'no Question', 'question_id': 259854000, 'question': ''}, {'answer_type': 'other', 'prediction': 'no Question', 'question_id': 390083002, 'question': ''}, {'answer_type': 'other', 'prediction': 'no Question', 'question_id': 391539000, 'question': ''}, {'answer_type': 'other', 'prediction': 'no Question', 'question_id': 395402005, 'question': ''}, {'answer_type': 'other', 'prediction': 'no Question', 'question_id': 413043011, 'question': ''}, {'answer_type': 'other', 'prediction': 'no Question', 'question_id': 462424001, 'question': ''}, {'answer_type': 'other', 'prediction': 'no Question', 'question_id': 482910001, 'question': ''}, {'answer_type': 'other', 'prediction': 'no Question', 'question_id': 495894018, 'question': ''}, {'answer_type': 'other', 'prediction': 'no Question', 'question_id': 503293002, 'question': ''}, {'answer_type': 'other', 'prediction': 'no Question', 'question_id': 577182003, 'question': ''}, {'answer_type': 'other', 'prediction': 'no Question', 'question_id': 578500001, 'question': ''}]
# 5 22
# licv.json
# [{'answer_type': 'yes/no', 'prediction': 'goatee', 'question_id': 417023010, 'question': 'Does the man have a goatee or crumbs on his chin?'}, {'answer_type': 'yes/no', 'prediction': 'turtles', 'question_id': 152499003, 'question': 'Are there ducks or turtles in the pond?'}, {'answer_type': 'yes/no', 'prediction': 'cargo', 'question_id': 451046002, 'question': 'Is it determinable if this train is carrying passengers or cargo?'}, {'answer_type': 'yes/no', 'prediction': 'tennis ball', 'question_id': 501898001, 'question': 'Is she hitting something?'}, {'answer_type': 'yes/no', 'prediction': 'boy', 'question_id': 371364010, 'question': 'Is the boy or the girl wearing glasses?'}]
# [{'answer_type': 'other', 'prediction': 'no', 'question_id': 5060000, 'question': 'Is there a painting or a mirror in the frame?'}, {'answer_type': 'other', 'prediction': 'yes', 'question_id': 578500001, 'question': 'Is there a framed painting or framed mirror above the couch?'}, {'answer_type': 'number', 'prediction': 'yes', 'question_id': 70256000, 'question': 'Have any slices been taken from this cake?'}, {'answer_type': 'number', 'prediction': 'yes', 'question_id': 38685000, 'question': 'How quickly can I get to the food market?  Is it accessible?'}]
# 5 4
# lora-r-16.json
# [{'answer_type': 'yes/no', 'prediction': 'cargo', 'question_id': 451046002, 'question': 'Is it determinable if this train is carrying passengers or cargo?'}, {'answer_type': 'yes/no', 'prediction': 'umbrellas', 'question_id': 317250002, 'question': 'Is there anything in the photo that would prevent a person from getting wet in the rain?'}, {'answer_type': 'yes/no', 'prediction': 'white', 'question_id': 479440017, 'question': 'Is the cat a solid color?'}, {'answer_type': 'yes/no', 'prediction': 'old', 'question_id': 479562006, 'question': 'What id woman married?'}, {'answer_type': 'yes/no', 'prediction': 'boy', 'question_id': 371364010, 'question': 'Is the boy or the girl wearing glasses?'}, {'answer_type': 'yes/no', 'prediction': 'old picture', 'question_id': 248019008, 'question': 'Is this old picture or what?'}]
# [{'answer_type': 'other', 'prediction': 'no', 'question_id': 528136021, 'question': 'Can you identify this job?'}, {'answer_type': 'other', 'prediction': 'yes', 'question_id': 5060000, 'question': 'Is there a painting or a mirror in the frame?'}, {'answer_type': 'other', 'prediction': 'yes', 'question_id': 138075001, 'question': 'Is there a child sitting down or a young person?'}, {'answer_type': 'other', 'prediction': 'no', 'question_id': 394460006, 'question': 'Is this space most likely an attic or a basement?'}, {'answer_type': 'other', 'prediction': 'no', 'question_id': 14276011, 'question': 'Does this animal have spots or stripes?'}, {'answer_type': 'other', 'prediction': 'no', 'question_id': 155317002, 'question': 'Is this a pizza or baked bread with toppings?'}, {'answer_type': 'other', 'prediction': 'yes', 'question_id': 163255000, 'question': 'Is the goblet more than or less than half full?'}, {'answer_type': 'other', 'prediction': 'no', 'question_id': 570394000, 'question': 'Is someone baking bread or cookies?'}, {'answer_type': 'other', 'prediction': 'no', 'question_id': 180167003, 'question': 'Is the animal on a tree branch or bush?'}, {'answer_type': 'other', 'prediction': 'yes', 'question_id': 578500001, 'question': 'Is there a framed painting or framed mirror above the couch?'}, {'answer_type': 'other', 'prediction': 'no', 'question_id': 64390003, 'question': 'Is the color of the is the stop light?'}, {'answer_type': 'number', 'prediction': 'no', 'question_id': 70256000, 'question': 'Have any slices been taken from this cake?'}, {'answer_type': 'other', 'prediction': 'yes', 'question_id': 82363006, 'question': 'Has the bathroom been recently used or is it clean?'}, {'answer_type': 'other', 'prediction': 'yes', 'question_id': 346207001, 'question': 'Is this a workstation for a person in school or a person doing work for a job?'}, {'answer_type': 'number', 'prediction': 'yes', 'question_id': 38685000, 'question': 'How quickly can I get to the food market?  Is it accessible?'}, {'answer_type': 'other', 'prediction': 'yes', 'question_id': 376677000, 'question': 'Does that look like a work or recreational truck?'}, {'answer_type': 'other', 'prediction': 'yes', 'question_id': 508489003, 'question': 'Are these items raised or grown?'}]
# 6 17
# mimic.json
# [{'answer_type': 'yes/no', 'prediction': 'No it is not.', 'question_id': 270215000, 'question': 'Yes it is?'}, {'answer_type': 'yes/no', 'prediction': 'goatee', 'question_id': 417023010, 'question': 'Does the man have a goatee or crumbs on his chin?'}, {'answer_type': 'yes/no', 'prediction': 'boy', 'question_id': 371364010, 'question': 'Is the boy or the girl wearing glasses?'}]
# [{'answer_type': 'other', 'prediction': 'No', 'question_id': 5060000, 'question': 'Is there a painting or a mirror in the frame?'}, {'answer_type': 'other', 'prediction': 'no', 'question_id': 578500001, 'question': 'Is there a framed painting or framed mirror above the couch?'}, {'answer_type': 'number', 'prediction': 'yes', 'question_id': 70256000, 'question': 'Have any slices been taken from this cake?'}, {'answer_type': 'other', 'prediction': 'yes', 'question_id': 82363006, 'question': 'Has the bathroom been recently used or is it clean?'}, {'answer_type': 'other', 'prediction': 'no', 'question_id': 370413001, 'question': 'What does the first word of the sign say?'}, {'answer_type': 'number', 'prediction': 'Yes', 'question_id': 38685000, 'question': 'How quickly can I get to the food market?  Is it accessible?'}, {'answer_type': 'other', 'prediction': 'No', 'question_id': 506574000, 'question': "How like an African savanna is the Giraffe's current home?"}, {'answer_type': 'other', 'prediction': 'yes', 'question_id': 246613009, 'question': 'Is this an actual bathroom or in a store?'}]
# 3 8
